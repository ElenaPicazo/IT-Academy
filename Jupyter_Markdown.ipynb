# %% [markdown]
# # Nivell 1
#
# - A
# - B
# - C
#
# **WARNING**
#
# *Esto es una prueba*
#
# > by Elena Picazo

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#!pip install nbconvert
#!pip install jupyter_contrib_nbextensions
#!pip install pandoc
#!pip install xelatex

# %% [markdown]
# in anaconda terminal:
#
# - From ipynb to pdf: jupyter nbconvert file.ipynb --to pdf --output file.pdf
# - From ipynb to html: jupyter nbconvert file.ipynb --to html --output file.html
